# %%
# test.py
import os
import tensorflow as tf
import numpy as np
import cv2

# module-level variables ##############################################################################################
RETRAINED_LABELS_TXT_FILE_LOC = os.getcwd() + "/" + "retrained_labels.txt"
RETRAINED_GRAPH_PB_FILE_LOC = os.getcwd() + "/" + "retrained_graph.pb"

TEST_IMAGES_DIR = os.getcwd() + "/specs/_test"

SCALAR_RED = (0.0, 0.0, 255.0)
SCALAR_BLUE = (255.0, 0.0, 0.0)

TP = {
    'classical': 0,
    'hiphop': 0,
    'jazz': 0,
    'metal': 0,
    'pop': 0,
    'reggae': 0
}
FP = {
    'classical': 0,
    'hiphop': 0,
    'jazz': 0,
    'metal': 0,
    'pop': 0,
    'reggae': 0
}
FN = {
    'classical': 0,
    'hiphop': 0,
    'jazz': 0,
    'metal': 0,
    'pop': 0,
    'reggae': 0
}

overallConfidence = {
    'classical': 0,
    'hiphop': 0,
    'jazz': 0,
    'metal': 0,
    'pop': 0,
    'reggae': 0
}

confidenceWhenRight = {
    'classical': 0,
    'hiphop': 0,
    'jazz': 0,
    'metal': 0,
    'pop': 0,
    'reggae': 0
}

confidenceWhenWrong = {
    'classical': 0,
    'hiphop': 0,
    'jazz': 0,
    'metal': 0,
    'pop': 0,
    'reggae': 0
}

dictionary = {}

#######################################################################################################################
def main():
    print("starting program . . .")

    if not checkIfNecessaryPathsAndFilesExist():
        return
    # end if
#######################################################################################################################


#######################################################################################################################

    # get a list of classifications from the labels file
    classifications = []
    # for each line in the label file . . .
    for currentLine in tf.gfile.GFile(RETRAINED_LABELS_TXT_FILE_LOC):
        # remove the carriage return
        classification = currentLine.rstrip()
        # and append to the list
        classifications.append(classification)
    # end for

    # show the classifications to prove out that we were able to read the label file successfully
    print("classifications = " + str(classifications))

    # load the graph from file
    with tf.gfile.FastGFile(RETRAINED_GRAPH_PB_FILE_LOC, 'rb') as retrainedGraphFile:
        # instantiate a GraphDef object
        graphDef = tf.GraphDef()
        # read in retrained graph into the GraphDef object
        graphDef.ParseFromString(retrainedGraphFile.read())
        # import the graph into the current default Graph, note that we don't need to be concerned with the return value
        _ = tf.import_graph_def(graphDef, name='')
    # end with

    # if the test image directory listed above is not valid, show an error message and bail
    if not os.path.isdir(TEST_IMAGES_DIR):
        print("the test image directory does not seem to be a valid directory, check file / directory paths")
        return
    # end if

    with tf.Session() as sess:
        # for each file in the test images directory . . .
        for fileName in os.listdir(TEST_IMAGES_DIR):
            # if the file does not end in .jpg or .jpeg (case-insensitive), continue with the next iteration of the for loop
            if not (fileName.lower().endswith(".jpg") or fileName.lower().endswith(".jpeg")):
                continue
            # end if

            # show the file name on std out
            print("\n" + fileName)

            # get the file name and full path of the current image file
            imageFileWithPath = os.path.join(TEST_IMAGES_DIR, fileName)
            # attempt to open the image with OpenCV
            openCVImage = cv2.imread(imageFileWithPath)

            # if we were not able to successfully open the image, continue with the next iteration of the for loop
            if openCVImage is None:
                print("unable to open " + fileName + " as an OpenCV image")
                continue
            # end if

            # get the final tensor from the graph
            finalTensor = sess.graph.get_tensor_by_name('final_result:0')

            # convert the OpenCV image (numpy array) to a TensorFlow image
            tfImage = np.array(openCVImage)[:, :, 0:3]
            
            # run the network to get the predictions
            predictions = sess.run(finalTensor, {'DecodeJpeg:0': tfImage})

            # sort predictions from most confidence to least confidence
            sortedPredictions = predictions[0].argsort()[-len(predictions[0]):][::-1]

            print("---------------------------------------")

            # keep track of if we're going through the next for loop for the first time so we can show more info about
            # the first prediction, which is the most likely prediction (they were sorted descending above)
            onMostLikelyPrediction = True
            # for each prediction . . .
            for prediction in sortedPredictions:
                strClassification = classifications[prediction]

                # if the classification (obtained from the directory name) ends with the letter "s", remove the "s" to change from plural to singular
                if strClassification.endswith("s"):
                    strClassification = strClassification[:-1]
                # end if

                # get confidence, then get confidence rounded to 2 places after the decimal
                confidence = predictions[0][prediction]

                # if we're on the first (most likely) prediction, state what the object appears to be and show a % confidence to two decimal places
                if onMostLikelyPrediction:
                    # get the score as a %
                    scoreAsAPercent = confidence * 100.0
                    # show the result to std out
                    print("the object appears to be " + strClassification + ", " + "{0:.2f}".format(scoreAsAPercent) + "% confidence")
                    # write the result on the image
#                     writeResultOnImage(openCVImage, strClassification + ", " + "{0:.2f}".format(scoreAsAPercent) + "% confidence")
                    # finally we can show the OpenCV image
#                     cv2.imshow(fileName, openCVImage)
                    # mark that we've show the most likely prediction at this point so the additional information in
                    # this if statement does not show again for this image
                    dictionary["{}".format(strClassification)] = "{0:.2f}".format(scoreAsAPercent)
                    overallConfidence[strClassification] += scoreAsAPercent
            
                    for genre in classifications:
                        if genre in fileName:
                            GENRE = genre
                    if strClassification in fileName:
                        confidenceWhenRight[strClassification] += scoreAsAPercent
                        TP[strClassification] += 1
                    else:
                        confidenceWhenWrong[GENRE] += scoreAsAPercent
                        FP[strClassification] += 1
                        FN[GENRE] +=1    
            
                onMostLikelyPrediction = False
                # end if
#######################################################################################################################

    
#######################################################################################################################
                
                # for any prediction, show the confidence as a ratio to five decimal places
                print(strClassification + " (" +  "{0:.5f}".format(confidence) + ")")
            # end for

            # pause until a key is pressed so the user can see the current image (shown above) and the prediction info
            cv2.waitKey()
            # after a key is pressed, close the current window to prep for the next time around
            cv2.destroyAllWindows()
        # end for
    # end with

    # write the graph to file so we can view with TensorBoard
    tfFileWriter = tf.summary.FileWriter(os.getcwd())
    tfFileWriter.add_graph(sess.graph)
    tfFileWriter.close()
#     print("\n Final Results")
#     print("-------------------------------------------------")
#     print(TP)
#     print(FP)
#     print(FN)
# end main

#######################################################################################################################
def checkIfNecessaryPathsAndFilesExist():
    if not os.path.exists(TEST_IMAGES_DIR):
        print('')
        print('ERROR: TEST_IMAGES_DIR "' + TEST_IMAGES_DIR + '" does not seem to exist')
        print('Did you set up the test images?')
        print('')
        return False
    # end if

    if not os.path.exists(RETRAINED_LABELS_TXT_FILE_LOC):
        print('ERROR: RETRAINED_LABELS_TXT_FILE_LOC "' + RETRAINED_LABELS_TXT_FILE_LOC + '" does not seem to exist')
        return False
    # end if

    if not os.path.exists(RETRAINED_GRAPH_PB_FILE_LOC):
        print('ERROR: RETRAINED_GRAPH_PB_FILE_LOC "' + RETRAINED_GRAPH_PB_FILE_LOC + '" does not seem to exist')
        return False
    # end if

    return True
# end function

if __name__ == "__main__":
    main()
# Out:
# starting program . . .
# classifications = ['classical', 'hiphop', 'jazz', 'metal', 'pop', 'reggae']
# WARNING:tensorflow:From <ipython-input-1-74e4926a462a>:96: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
#
# classical.00000.jpg
# ---------------------------------------
# the object appears to be classical, 43.43% confidence
# classical (0.43432)
# pop (0.20580)
# jazz (0.18157)
# reggae (0.11214)
# hiphop (0.03517)
# metal (0.03100)
#
# classical.00001.jpg
# ---------------------------------------
# the object appears to be classical, 35.59% confidence
# classical (0.35590)
# jazz (0.28344)
# pop (0.24993)
# reggae (0.05623)
# metal (0.04128)
# hiphop (0.01322)
#
# classical.00002.jpg
# ---------------------------------------
# the object appears to be jazz, 33.84% confidence
# jazz (0.33844)
# pop (0.24301)
# classical (0.24184)
# metal (0.09229)
# reggae (0.05631)
# hiphop (0.02810)
#
# classical.00003.jpg
# ---------------------------------------
# the object appears to be classical, 71.39% confidence
# classical (0.71394)
# jazz (0.16495)
# pop (0.09107)
# reggae (0.02115)
# metal (0.00630)
# hiphop (0.00258)
#
# classical.00004.jpg
# ---------------------------------------
# the object appears to be classical, 42.15% confidence
# classical (0.42155)
# pop (0.36677)
# jazz (0.09736)
# reggae (0.05441)
# hiphop (0.04392)
# metal (0.01600)
#
# classical.00005.jpg
# ---------------------------------------
# the object appears to be classical, 83.28% confidence
# classical (0.83282)
# jazz (0.08810)
# pop (0.03994)
# reggae (0.02668)
# metal (0.00883)
# hiphop (0.00362)
#
# classical.00006.jpg
# ---------------------------------------
# the object appears to be classical, 81.28% confidence
# classical (0.81281)
# jazz (0.09935)
# reggae (0.04079)
# pop (0.02435)
# metal (0.01805)
# hiphop (0.00465)
#
# classical.00007.jpg
# ---------------------------------------
# the object appears to be classical, 85.69% confidence
# classical (0.85692)
# jazz (0.08317)
# pop (0.02867)
# reggae (0.02429)
# metal (0.00525)
# hiphop (0.00170)
#
# classical.00008.jpg
# ---------------------------------------
# the object appears to be classical, 68.65% confidence
# classical (0.68650)
# jazz (0.17923)
# reggae (0.05954)
# pop (0.04800)
# metal (0.01644)
# hiphop (0.01029)
#
# classical.00009.jpg
# ---------------------------------------
# the object appears to be classical, 89.94% confidence
# classical (0.89939)
# jazz (0.05215)
# pop (0.03410)
# reggae (0.00947)
# metal (0.00352)
# hiphop (0.00136)
#
# hiphop.00000.jpg
# ---------------------------------------
# the object appears to be hiphop, 51.21% confidence
# hiphop (0.51211)
# pop (0.20034)
# reggae (0.11862)
# metal (0.07539)
# jazz (0.05343)
# classical (0.04012)
#
# hiphop.00001.jpg
# ---------------------------------------
# the object appears to be hiphop, 59.94% confidence
# hiphop (0.59941)
# pop (0.26987)
# reggae (0.08826)
# metal (0.02009)
# jazz (0.01274)
# classical (0.00963)
#
# hiphop.00002.jpg
# ---------------------------------------
# the object appears to be hiphop, 53.40% confidence
# hiphop (0.53402)
# reggae (0.18980)
# pop (0.17764)
# jazz (0.04743)
# metal (0.03884)
# classical (0.01227)
#
# hiphop.00003.jpg
# ---------------------------------------
# the object appears to be hiphop, 58.58% confidence
# hiphop (0.58579)
# pop (0.23104)
# reggae (0.08098)
# metal (0.05906)
# jazz (0.04021)
# classical (0.00292)
#
# hiphop.00004.jpg
# ---------------------------------------
# the object appears to be hiphop, 42.81% confidence
# hiphop (0.42811)
# reggae (0.28732)
# pop (0.20830)
# jazz (0.04523)
# metal (0.02765)
# classical (0.00339)
#
# hiphop.00005.jpg
# ---------------------------------------
# the object appears to be hiphop, 52.69% confidence
# hiphop (0.52692)
# pop (0.21018)
# reggae (0.13341)
# metal (0.09677)
# jazz (0.02807)
# classical (0.00466)
#
# hiphop.00006.jpg
# ---------------------------------------
# the object appears to be hiphop, 49.02% confidence
# hiphop (0.49022)
# pop (0.34679)
# reggae (0.07937)
# jazz (0.05507)
# metal (0.02449)
# classical (0.00405)
#
# hiphop.00007.jpg
# ---------------------------------------
# the object appears to be metal, 47.79% confidence
# metal (0.47791)
# pop (0.20110)
# hiphop (0.14127)
# jazz (0.10957)
# reggae (0.06960)
# classical (0.00055)
#
# hiphop.00008.jpg
# ---------------------------------------
# the object appears to be hiphop, 57.76% confidence
# hiphop (0.57762)
# reggae (0.19155)
# pop (0.18975)
# jazz (0.01957)
# metal (0.01271)
# classical (0.00879)
#
# hiphop.00009.jpg
# ---------------------------------------
# the object appears to be hiphop, 53.96% confidence
# hiphop (0.53958)
# pop (0.19278)
# reggae (0.11330)
# jazz (0.09599)
# metal (0.05240)
# classical (0.00595)
#
# jazz.00000.jpg
# ---------------------------------------
# the object appears to be jazz, 30.00% confidence
# jazz (0.30000)
# classical (0.26714)
# metal (0.15314)
# reggae (0.13072)
# pop (0.10239)
# hiphop (0.04661)
#
# jazz.00001.jpg
# ---------------------------------------
# the object appears to be jazz, 49.32% confidence
# jazz (0.49322)
# classical (0.16360)
# metal (0.13960)
# reggae (0.11108)
# pop (0.06377)
# hiphop (0.02874)
#
# jazz.00002.jpg
# ---------------------------------------
# the object appears to be jazz, 71.15% confidence
# jazz (0.71151)
# classical (0.25172)
# pop (0.02324)
# hiphop (0.00515)
# reggae (0.00452)
# metal (0.00386)
#
# jazz.00003.jpg
# ---------------------------------------
# the object appears to be classical, 57.75% confidence
# classical (0.57752)
# jazz (0.25945)
# metal (0.09747)
# pop (0.02889)
# reggae (0.02488)
# hiphop (0.01179)
#
# jazz.00004.jpg
# ---------------------------------------
# the object appears to be jazz, 89.48% confidence
# jazz (0.89478)
# classical (0.04466)
# pop (0.04154)
# metal (0.01045)
# reggae (0.00541)
# hiphop (0.00315)
#
# jazz.00005.jpg
# ---------------------------------------
# the object appears to be jazz, 70.87% confidence
# jazz (0.70870)
# classical (0.16060)
# metal (0.06712)
# reggae (0.02842)
# hiphop (0.01977)
# pop (0.01540)
#
# jazz.00006.jpg
# ---------------------------------------
# the object appears to be jazz, 70.51% confidence
# jazz (0.70512)
# classical (0.10340)
# metal (0.08038)
# pop (0.06306)
# reggae (0.03251)
# hiphop (0.01552)
#
# jazz.00007.jpg
# ---------------------------------------
# the object appears to be jazz, 72.47% confidence
# jazz (0.72474)
# pop (0.17439)
# metal (0.04859)
# classical (0.02173)
# hiphop (0.01718)
# reggae (0.01336)
#
# jazz.00008.jpg
# ---------------------------------------
# the object appears to be jazz, 70.93% confidence
# jazz (0.70934)
# metal (0.20245)
# reggae (0.02830)
# pop (0.02588)
# classical (0.02583)
# hiphop (0.00821)
#
# jazz.00009.jpg
# ---------------------------------------
# the object appears to be metal, 35.65% confidence
# metal (0.35648)
# jazz (0.28697)
# pop (0.20441)
# classical (0.07208)
# reggae (0.04700)
# hiphop (0.03306)
#
# metal.00000.jpg
# ---------------------------------------
# the object appears to be metal, 47.43% confidence
# metal (0.47430)
# jazz (0.38257)
# pop (0.09399)
# hiphop (0.03639)
# reggae (0.00864)
# classical (0.00411)
#
# metal.00001.jpg
# ---------------------------------------
# the object appears to be metal, 80.12% confidence
# metal (0.80120)
# jazz (0.13005)
# pop (0.04172)
# hiphop (0.01675)
# reggae (0.00871)
# classical (0.00157)
#
# metal.00002.jpg
# ---------------------------------------
# the object appears to be pop, 27.12% confidence
# pop (0.27117)
# metal (0.26574)
# jazz (0.18473)
# hiphop (0.15002)
# reggae (0.09205)
# classical (0.03629)
#
# metal.00003.jpg
# ---------------------------------------
# the object appears to be metal, 63.68% confidence
# metal (0.63676)
# pop (0.16515)
# jazz (0.13338)
# hiphop (0.04415)
# reggae (0.01744)
# classical (0.00312)
#
# metal.00004.jpg
# ---------------------------------------
# the object appears to be metal, 63.53% confidence
# metal (0.63530)
# hiphop (0.16400)
# jazz (0.09726)
# pop (0.05918)
# reggae (0.03231)
# classical (0.01195)
#
# metal.00005.jpg
# ---------------------------------------
# the object appears to be metal, 52.06% confidence
# metal (0.52056)
# jazz (0.23265)
# hiphop (0.12639)
# pop (0.08034)
# reggae (0.02930)
# classical (0.01075)
#
# metal.00006.jpg
# ---------------------------------------
# the object appears to be jazz, 37.16% confidence
# jazz (0.37161)
# metal (0.26715)
# pop (0.15822)
# hiphop (0.12916)
# reggae (0.04318)
# classical (0.03067)
#
# metal.00007.jpg
# ---------------------------------------
# the object appears to be metal, 63.79% confidence
# metal (0.63792)
# pop (0.15319)
# jazz (0.09635)
# hiphop (0.07047)
# reggae (0.02329)
# classical (0.01878)
#
# metal.00008.jpg
# ---------------------------------------
# the object appears to be metal, 45.08% confidence
# metal (0.45077)
# jazz (0.24063)
# pop (0.18069)
# hiphop (0.09927)
# reggae (0.02229)
# classical (0.00635)
#
# metal.00009.jpg
# ---------------------------------------
# the object appears to be metal, 70.67% confidence
# metal (0.70668)
# jazz (0.10928)
# pop (0.08598)
# hiphop (0.06770)
# reggae (0.02847)
# classical (0.00189)
#
# pop.00000.jpg
# ---------------------------------------
# the object appears to be pop, 46.75% confidence
# pop (0.46754)
# jazz (0.33207)
# metal (0.08288)
# hiphop (0.05761)
# reggae (0.05058)
# classical (0.00932)
#
# pop.00001.jpg
# ---------------------------------------
# the object appears to be pop, 65.01% confidence
# pop (0.65014)
# hiphop (0.17109)
# reggae (0.07002)
# jazz (0.05463)
# metal (0.05259)
# classical (0.00154)
#
# pop.00002.jpg
# ---------------------------------------
# the object appears to be jazz, 30.61% confidence
# jazz (0.30610)
# pop (0.30518)
# metal (0.28943)
# hiphop (0.03833)
# classical (0.03075)
# reggae (0.03020)
#
# pop.00003.jpg
# ---------------------------------------
# the object appears to be metal, 68.46% confidence
# metal (0.68462)
# pop (0.11597)
# jazz (0.09237)
# hiphop (0.06713)
# reggae (0.03854)
# classical (0.00137)
#
# pop.00004.jpg
# ---------------------------------------
# the object appears to be jazz, 48.95% confidence
# jazz (0.48947)
# metal (0.42214)
# pop (0.04859)
# reggae (0.02193)
# hiphop (0.01670)
# classical (0.00116)
#
# pop.00005.jpg
# ---------------------------------------
# the object appears to be jazz, 78.79% confidence
# jazz (0.78792)
# pop (0.08777)
# metal (0.06414)
# hiphop (0.02709)
# classical (0.01888)
# reggae (0.01420)
#
# pop.00006.jpg
# ---------------------------------------
# the object appears to be jazz, 48.12% confidence
# jazz (0.48122)
# metal (0.30474)
# pop (0.09093)
# reggae (0.06322)
# hiphop (0.05300)
# classical (0.00689)
#
# pop.00007.jpg
# ---------------------------------------
# the object appears to be jazz, 77.30% confidence
# jazz (0.77298)
# pop (0.14308)
# metal (0.03059)
# classical (0.02940)
# reggae (0.01407)
# hiphop (0.00987)
#
# pop.00008.jpg
# ---------------------------------------
# the object appears to be jazz, 59.58% confidence
# jazz (0.59579)
# metal (0.21704)
# pop (0.13453)
# reggae (0.02334)
# hiphop (0.01967)
# classical (0.00964)
#
# pop.00009.jpg
# ---------------------------------------
# the object appears to be metal, 46.29% confidence
# metal (0.46290)
# jazz (0.21667)
# pop (0.16932)
# hiphop (0.11519)
# reggae (0.03316)
# classical (0.00275)
#
# reggae.00000.jpg
# ---------------------------------------
# the object appears to be jazz, 35.61% confidence
# jazz (0.35613)
# pop (0.28030)
# reggae (0.20822)
# metal (0.08148)
# classical (0.03739)
# hiphop (0.03649)
#
# reggae.00001.jpg
# ---------------------------------------
# the object appears to be metal, 57.14% confidence
# metal (0.57141)
# jazz (0.17699)
# pop (0.12987)
# hiphop (0.05923)
# reggae (0.05401)
# classical (0.00848)
#
# reggae.00002.jpg
# ---------------------------------------
# the object appears to be pop, 33.28% confidence
# pop (0.33281)
# hiphop (0.29385)
# reggae (0.27851)
# metal (0.05500)
# jazz (0.03257)
# classical (0.00726)
#
# reggae.00003.jpg
# ---------------------------------------
# the object appears to be metal, 37.06% confidence
# metal (0.37060)
# reggae (0.28241)
# jazz (0.13993)
# pop (0.13020)
# hiphop (0.06855)
# classical (0.00832)
#
# reggae.00004.jpg
# ---------------------------------------
# the object appears to be reggae, 37.86% confidence
# reggae (0.37858)
# pop (0.37173)
# hiphop (0.08547)
# jazz (0.08407)
# classical (0.05654)
# metal (0.02360)
#
# reggae.00005.jpg
# ---------------------------------------
# the object appears to be reggae, 35.41% confidence
# reggae (0.35409)
# hiphop (0.23620)
# pop (0.16190)
# metal (0.12391)
# jazz (0.08878)
# classical (0.03512)
#
# reggae.00006.jpg
# ---------------------------------------
# the object appears to be reggae, 39.55% confidence
# reggae (0.39545)
# jazz (0.19713)
# pop (0.19350)
# metal (0.12845)
# hiphop (0.04986)
# classical (0.03561)
#
# reggae.00007.jpg
# ---------------------------------------
# the object appears to be reggae, 60.07% confidence
# reggae (0.60066)
# pop (0.14445)
# hiphop (0.11516)
# metal (0.09033)
# jazz (0.03578)
# classical (0.01362)
#
# reggae.00008.jpg
# ---------------------------------------
# the object appears to be pop, 40.18% confidence
# pop (0.40181)
# jazz (0.31434)
# reggae (0.12282)
# metal (0.11564)
# hiphop (0.03266)
# classical (0.01272)
#
# reggae.00009.jpg
# ---------------------------------------
# the object appears to be reggae, 51.04% confidence
# reggae (0.51035)
# metal (0.20216)
# jazz (0.10875)
# hiphop (0.09964)
# pop (0.07586)
# classical (0.00324)

# %%
print("True positives")
print(TP)
print("False negatives")
print(FN)
print("False positives")
print(FP)

TN = {
'classical': 0,
'hiphop': 0,
'jazz': 0,
'metal': 0,
'pop': 0,
'reggae': 0
}

for genre in TN.keys():
    TN[genre] = 50 - FP[genre]
print("True Negatives")
print(TN)

accuracy = 0
total = 0

for genre in TP.keys():
    accuracy += TP[genre]
    total += TP[genre]

for genre in FP.keys():
    total += FN[genre]

accuracy /= (total/100)
# print(total)
print("Accuracy = " + str(accuracy))

# for genre in overallConfidence.keys():
#     overallConfidence[genre] /= 10
#     confidenceWhenWrong[genre] /= 10
#     confidenceWhenRight[genre] /= 10

# print(overallConfidence)
# print(confidenceWhenWrong)
# print(confidenceWhenRight)
# Out:
# True positives
# {'classical': 9, 'hiphop': 9, 'jazz': 8, 'metal': 8, 'pop': 2, 'reggae': 5}
# False negatives
# {'classical': 1, 'hiphop': 1, 'jazz': 2, 'metal': 2, 'pop': 8, 'reggae': 5}
# False positives
# {'classical': 1, 'hiphop': 0, 'jazz': 9, 'metal': 6, 'pop': 3, 'reggae': 0}
# True Negatives
# {'classical': 49, 'hiphop': 50, 'jazz': 41, 'metal': 44, 'pop': 47, 'reggae': 50}
# Accuracy = 68.33333333333334

# %%
precision = {
'classical': 0,
'hiphop': 0,
'jazz': 0,
'metal': 0,
'pop': 0,
'reggae': 0
}
recall = {
'classical': 0,
'hiphop': 0,
'jazz': 0,
'metal': 0,
'pop': 0,
'reggae': 0
}

for genre in precision.keys():
    precision[genre] = TP[genre] / (TP[genre] + FP[genre])
    precision[genre] = "{0:.2f}".format(precision[genre])
    recall[genre] = TP[genre] / (TP[genre] + FN[genre])
    recall[genre] = "{0:.2f}".format(recall[genre])
    
print("Precision")
print(precision)
print("Recall")
print(recall)
# Out:
# Precision
# {'classical': '0.90', 'hiphop': '1.00', 'jazz': '0.47', 'metal': '0.57', 'pop': '0.40', 'reggae': '1.00'}
# Recall
# {'classical': '0.90', 'hiphop': '0.90', 'jazz': '0.80', 'metal': '0.80', 'pop': '0.20', 'reggae': '0.50'}
