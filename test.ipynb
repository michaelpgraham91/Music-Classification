# %%
# test.py
import os
import tensorflow as tf
import numpy as np
import cv2

# module-level variables ##############################################################################################
RETRAINED_LABELS_TXT_FILE_LOC = os.getcwd() + "/" + "retrained_labels.txt"
RETRAINED_GRAPH_PB_FILE_LOC = os.getcwd() + "/" + "retrained_graph.pb"

TEST_IMAGES_DIR = os.getcwd() + "/specs/_test"

SCALAR_RED = (0.0, 0.0, 255.0)
SCALAR_BLUE = (255.0, 0.0, 0.0)

TP = {
    'classical': 0,
    'hiphop': 0,
    'jazz': 0,
    'metal': 0,
    'pop': 0,
    'reggae': 0
}
FP = {
    'classical': 0,
    'hiphop': 0,
    'jazz': 0,
    'metal': 0,
    'pop': 0,
    'reggae': 0
}
FN = {
    'classical': 0,
    'hiphop': 0,
    'jazz': 0,
    'metal': 0,
    'pop': 0,
    'reggae': 0
}

overallConfidence = {
    'classical': 0,
    'hiphop': 0,
    'jazz': 0,
    'metal': 0,
    'pop': 0,
    'reggae': 0
}

confidenceWhenRight = {
    'classical': 0,
    'hiphop': 0,
    'jazz': 0,
    'metal': 0,
    'pop': 0,
    'reggae': 0
}

confidenceWhenWrong = {
    'classical': 0,
    'hiphop': 0,
    'jazz': 0,
    'metal': 0,
    'pop': 0,
    'reggae': 0
}

dictionary = {}

#######################################################################################################################
def main():
    print("starting program . . .")

    if not checkIfNecessaryPathsAndFilesExist():
        return
    # end if
#######################################################################################################################


#######################################################################################################################

    # get a list of classifications from the labels file
    classifications = []
    # for each line in the label file . . .
    for currentLine in tf.gfile.GFile(RETRAINED_LABELS_TXT_FILE_LOC):
        # remove the carriage return
        classification = currentLine.rstrip()
        # and append to the list
        classifications.append(classification)
    # end for

    # show the classifications to prove out that we were able to read the label file successfully
    print("classifications = " + str(classifications))

    # load the graph from file
    with tf.gfile.FastGFile(RETRAINED_GRAPH_PB_FILE_LOC, 'rb') as retrainedGraphFile:
        # instantiate a GraphDef object
        graphDef = tf.GraphDef()
        # read in retrained graph into the GraphDef object
        graphDef.ParseFromString(retrainedGraphFile.read())
        # import the graph into the current default Graph, note that we don't need to be concerned with the return value
        _ = tf.import_graph_def(graphDef, name='')
    # end with

    # if the test image directory listed above is not valid, show an error message and bail
    if not os.path.isdir(TEST_IMAGES_DIR):
        print("the test image directory does not seem to be a valid directory, check file / directory paths")
        return
    # end if

    with tf.Session() as sess:
        # for each file in the test images directory . . .
        for fileName in os.listdir(TEST_IMAGES_DIR):
            # if the file does not end in .jpg or .jpeg (case-insensitive), continue with the next iteration of the for loop
            if not (fileName.lower().endswith(".jpg") or fileName.lower().endswith(".jpeg")):
                continue
            # end if

            # show the file name on std out
            print("\n" + fileName)

            # get the file name and full path of the current image file
            imageFileWithPath = os.path.join(TEST_IMAGES_DIR, fileName)
            # attempt to open the image with OpenCV
            openCVImage = cv2.imread(imageFileWithPath)

            # if we were not able to successfully open the image, continue with the next iteration of the for loop
            if openCVImage is None:
                print("unable to open " + fileName + " as an OpenCV image")
                continue
            # end if

            # get the final tensor from the graph
            finalTensor = sess.graph.get_tensor_by_name('final_result:0')

            # convert the OpenCV image (numpy array) to a TensorFlow image
            tfImage = np.array(openCVImage)[:, :, 0:3]
            
            # run the network to get the predictions
            predictions = sess.run(finalTensor, {'DecodeJpeg:0': tfImage})

            # sort predictions from most confidence to least confidence
            sortedPredictions = predictions[0].argsort()[-len(predictions[0]):][::-1]

            print("---------------------------------------")

            # keep track of if we're going through the next for loop for the first time so we can show more info about
            # the first prediction, which is the most likely prediction (they were sorted descending above)
            onMostLikelyPrediction = True
            # for each prediction . . .
            for prediction in sortedPredictions:
                strClassification = classifications[prediction]

                # if the classification (obtained from the directory name) ends with the letter "s", remove the "s" to change from plural to singular
                if strClassification.endswith("s"):
                    strClassification = strClassification[:-1]
                # end if

                # get confidence, then get confidence rounded to 2 places after the decimal
                confidence = predictions[0][prediction]

                # if we're on the first (most likely) prediction, state what the object appears to be and show a % confidence to two decimal places
                if onMostLikelyPrediction:
                    # get the score as a %
                    scoreAsAPercent = confidence * 100.0
                    # show the result to std out
                    print("the object appears to be " + strClassification + ", " + "{0:.2f}".format(scoreAsAPercent) + "% confidence")
                    # write the result on the image
#                     writeResultOnImage(openCVImage, strClassification + ", " + "{0:.2f}".format(scoreAsAPercent) + "% confidence")
                    # finally we can show the OpenCV image
#                     cv2.imshow(fileName, openCVImage)
                    # mark that we've show the most likely prediction at this point so the additional information in
                    # this if statement does not show again for this image
                    dictionary["{}".format(strClassification)] = "{0:.2f}".format(scoreAsAPercent)
                    overallConfidence[strClassification] += scoreAsAPercent
            
                    for genre in classifications:
                        if genre in fileName:
                            GENRE = genre
                    if strClassification in fileName:
                        confidenceWhenRight[strClassification] += scoreAsAPercent
                        TP[strClassification] += 1
                    else:
                        confidenceWhenWrong[GENRE] += scoreAsAPercent
                        FP[strClassification] += 1
                        FN[GENRE] +=1    
            
                onMostLikelyPrediction = False
                # end if
#######################################################################################################################

    
#######################################################################################################################
                
                # for any prediction, show the confidence as a ratio to five decimal places
                print(strClassification + " (" +  "{0:.5f}".format(confidence) + ")")
            # end for

            # pause until a key is pressed so the user can see the current image (shown above) and the prediction info
            cv2.waitKey()
            # after a key is pressed, close the current window to prep for the next time around
            cv2.destroyAllWindows()
        # end for
    # end with

    # write the graph to file so we can view with TensorBoard
    tfFileWriter = tf.summary.FileWriter(os.getcwd())
    tfFileWriter.add_graph(sess.graph)
    tfFileWriter.close()
#     print("\n Final Results")
#     print("-------------------------------------------------")
#     print(TP)
#     print(FP)
#     print(FN)
# end main

#######################################################################################################################
def checkIfNecessaryPathsAndFilesExist():
    if not os.path.exists(TEST_IMAGES_DIR):
        print('')
        print('ERROR: TEST_IMAGES_DIR "' + TEST_IMAGES_DIR + '" does not seem to exist')
        print('Did you set up the test images?')
        print('')
        return False
    # end if

    if not os.path.exists(RETRAINED_LABELS_TXT_FILE_LOC):
        print('ERROR: RETRAINED_LABELS_TXT_FILE_LOC "' + RETRAINED_LABELS_TXT_FILE_LOC + '" does not seem to exist')
        return False
    # end if

    if not os.path.exists(RETRAINED_GRAPH_PB_FILE_LOC):
        print('ERROR: RETRAINED_GRAPH_PB_FILE_LOC "' + RETRAINED_GRAPH_PB_FILE_LOC + '" does not seem to exist')
        return False
    # end if

    return True
# end function

if __name__ == "__main__":
    main()
# Out:
# starting program . . .
# classifications = ['classical', 'hiphop', 'jazz', 'metal', 'pop', 'reggae']
#
# classical.00000.jpg
# ---------------------------------------
# the object appears to be classical, 41.08% confidence
# classical (0.41081)
# pop (0.22580)
# jazz (0.17063)
# reggae (0.13048)
# hiphop (0.03261)
# metal (0.02966)
#
# classical.00001.jpg
# ---------------------------------------
# the object appears to be classical, 33.55% confidence
# classical (0.33547)
# pop (0.27737)
# jazz (0.27174)
# reggae (0.06487)
# metal (0.03791)
# hiphop (0.01263)
#
# classical.00002.jpg
# ---------------------------------------
# the object appears to be jazz, 32.67% confidence
# jazz (0.32667)
# pop (0.26611)
# classical (0.22908)
# metal (0.08451)
# reggae (0.06629)
# hiphop (0.02733)
#
# classical.00003.jpg
# ---------------------------------------
# the object appears to be classical, 70.56% confidence
# classical (0.70559)
# jazz (0.16270)
# pop (0.10036)
# reggae (0.02293)
# metal (0.00589)
# hiphop (0.00253)
#
# classical.00004.jpg
# ---------------------------------------
# the object appears to be classical, 39.68% confidence
# classical (0.39682)
# pop (0.39115)
# jazz (0.09080)
# reggae (0.06484)
# hiphop (0.04137)
# metal (0.01502)
#
# classical.00005.jpg
# ---------------------------------------
# the object appears to be classical, 82.45% confidence
# classical (0.82447)
# jazz (0.08842)
# pop (0.04542)
# reggae (0.02960)
# metal (0.00855)
# hiphop (0.00354)
#
# classical.00006.jpg
# ---------------------------------------
# the object appears to be classical, 81.09% confidence
# classical (0.81091)
# jazz (0.09460)
# reggae (0.04609)
# pop (0.02671)
# metal (0.01742)
# hiphop (0.00426)
#
# classical.00007.jpg
# ---------------------------------------
# the object appears to be classical, 85.19% confidence
# classical (0.85195)
# jazz (0.08174)
# pop (0.03274)
# reggae (0.02686)
# metal (0.00508)
# hiphop (0.00163)
#
# classical.00008.jpg
# ---------------------------------------
# the object appears to be classical, 67.65% confidence
# classical (0.67652)
# jazz (0.17721)
# reggae (0.06529)
# pop (0.05533)
# metal (0.01570)
# hiphop (0.00995)
#
# classical.00009.jpg
# ---------------------------------------
# the object appears to be classical, 89.60% confidence
# classical (0.89601)
# jazz (0.05123)
# pop (0.03791)
# reggae (0.01015)
# metal (0.00339)
# hiphop (0.00130)
#
# hiphop.00000.jpg
# ---------------------------------------
# the object appears to be hiphop, 47.88% confidence
# hiphop (0.47883)
# pop (0.21904)
# reggae (0.13228)
# metal (0.07567)
# jazz (0.05527)
# classical (0.03890)
#
# hiphop.00001.jpg
# ---------------------------------------
# the object appears to be hiphop, 58.13% confidence
# hiphop (0.58134)
# pop (0.27306)
# reggae (0.10480)
# metal (0.01892)
# jazz (0.01275)
# classical (0.00913)
#
# hiphop.00002.jpg
# ---------------------------------------
# the object appears to be hiphop, 49.23% confidence
# hiphop (0.49226)
# reggae (0.22076)
# pop (0.19024)
# jazz (0.05045)
# metal (0.03476)
# classical (0.01152)
#
# hiphop.00003.jpg
# ---------------------------------------
# the object appears to be hiphop, 56.14% confidence
# hiphop (0.56139)
# pop (0.24204)
# reggae (0.09633)
# metal (0.05465)
# jazz (0.04278)
# classical (0.00281)
#
# hiphop.00004.jpg
# ---------------------------------------
# the object appears to be hiphop, 37.96% confidence
# hiphop (0.37962)
# reggae (0.32214)
# pop (0.22388)
# jazz (0.04614)
# metal (0.02508)
# classical (0.00314)
#
# hiphop.00005.jpg
# ---------------------------------------
# the object appears to be hiphop, 49.23% confidence
# hiphop (0.49229)
# pop (0.22351)
# reggae (0.15547)
# metal (0.09619)
# jazz (0.02811)
# classical (0.00443)
#
# hiphop.00006.jpg
# ---------------------------------------
# the object appears to be hiphop, 46.13% confidence
# hiphop (0.46135)
# pop (0.36770)
# reggae (0.08917)
# jazz (0.05647)
# metal (0.02149)
# classical (0.00383)
#
# hiphop.00007.jpg
# ---------------------------------------
# the object appears to be metal, 43.73% confidence
# metal (0.43728)
# pop (0.21971)
# hiphop (0.13964)
# jazz (0.11873)
# reggae (0.08411)
# classical (0.00053)
#
# hiphop.00008.jpg
# ---------------------------------------
# the object appears to be hiphop, 53.40% confidence
# hiphop (0.53401)
# pop (0.21341)
# reggae (0.21073)
# jazz (0.02079)
# metal (0.01233)
# classical (0.00874)
#
# hiphop.00009.jpg
# ---------------------------------------
# the object appears to be hiphop, 50.97% confidence
# hiphop (0.50968)
# pop (0.20921)
# reggae (0.12553)
# jazz (0.10292)
# metal (0.04710)
# classical (0.00556)
#
# jazz.00000.jpg
# ---------------------------------------
# the object appears to be jazz, 31.07% confidence
# jazz (0.31065)
# classical (0.25620)
# metal (0.14050)
# reggae (0.13910)
# pop (0.11013)
# hiphop (0.04342)
#
# jazz.00001.jpg
# ---------------------------------------
# the object appears to be jazz, 50.39% confidence
# jazz (0.50386)
# classical (0.15466)
# metal (0.13007)
# reggae (0.11953)
# pop (0.06647)
# hiphop (0.02541)
#
# jazz.00002.jpg
# ---------------------------------------
# the object appears to be jazz, 73.33% confidence
# jazz (0.73330)
# classical (0.23197)
# pop (0.02212)
# hiphop (0.00474)
# reggae (0.00441)
# metal (0.00347)
#
# jazz.00003.jpg
# ---------------------------------------
# the object appears to be classical, 57.02% confidence
# classical (0.57023)
# jazz (0.26643)
# metal (0.08994)
# pop (0.03305)
# reggae (0.02816)
# hiphop (0.01219)
#
# jazz.00004.jpg
# ---------------------------------------
# the object appears to be jazz, 90.54% confidence
# jazz (0.90537)
# pop (0.03902)
# classical (0.03885)
# metal (0.00867)
# reggae (0.00518)
# hiphop (0.00291)
#
# jazz.00005.jpg
# ---------------------------------------
# the object appears to be jazz, 73.60% confidence
# jazz (0.73601)
# classical (0.14345)
# metal (0.05750)
# reggae (0.02987)
# hiphop (0.01729)
# pop (0.01588)
#
# jazz.00006.jpg
# ---------------------------------------
# the object appears to be jazz, 72.28% confidence
# jazz (0.72281)
# classical (0.09627)
# metal (0.06854)
# pop (0.06504)
# reggae (0.03403)
# hiphop (0.01331)
#
# jazz.00007.jpg
# ---------------------------------------
# the object appears to be jazz, 74.88% confidence
# jazz (0.74880)
# pop (0.16099)
# metal (0.04255)
# classical (0.01895)
# hiphop (0.01563)
# reggae (0.01308)
#
# jazz.00008.jpg
# ---------------------------------------
# the object appears to be jazz, 74.28% confidence
# jazz (0.74281)
# metal (0.16847)
# reggae (0.03108)
# pop (0.02736)
# classical (0.02307)
# hiphop (0.00721)
#
# jazz.00009.jpg
# ---------------------------------------
# the object appears to be metal, 32.78% confidence
# metal (0.32781)
# jazz (0.30004)
# pop (0.21914)
# classical (0.06849)
# reggae (0.05315)
# hiphop (0.03139)
#
# metal.00000.jpg
# ---------------------------------------
# the object appears to be metal, 43.99% confidence
# metal (0.43989)
# jazz (0.40255)
# pop (0.10466)
# hiphop (0.03817)
# reggae (0.01068)
# classical (0.00405)
#
# metal.00001.jpg
# ---------------------------------------
# the object appears to be metal, 78.09% confidence
# metal (0.78088)
# jazz (0.14271)
# pop (0.04693)
# hiphop (0.01717)
# reggae (0.01078)
# classical (0.00154)
#
# metal.00002.jpg
# ---------------------------------------
# the object appears to be pop, 28.89% confidence
# pop (0.28890)
# metal (0.24435)
# jazz (0.18456)
# hiphop (0.14224)
# reggae (0.10647)
# classical (0.03348)
#
# metal.00003.jpg
# ---------------------------------------
# the object appears to be metal, 61.29% confidence
# metal (0.61290)
# pop (0.17610)
# jazz (0.14314)
# hiphop (0.04437)
# reggae (0.02047)
# classical (0.00302)
#
# metal.00004.jpg
# ---------------------------------------
# the object appears to be metal, 62.81% confidence
# metal (0.62810)
# hiphop (0.15087)
# jazz (0.10526)
# pop (0.06382)
# reggae (0.03970)
# classical (0.01225)
#
# metal.00005.jpg
# ---------------------------------------
# the object appears to be metal, 49.43% confidence
# metal (0.49434)
# jazz (0.24804)
# hiphop (0.12374)
# pop (0.08947)
# reggae (0.03394)
# classical (0.01047)
#
# metal.00006.jpg
# ---------------------------------------
# the object appears to be jazz, 38.85% confidence
# jazz (0.38850)
# metal (0.24732)
# pop (0.16427)
# hiphop (0.12282)
# reggae (0.04907)
# classical (0.02802)
#
# metal.00007.jpg
# ---------------------------------------
# the object appears to be metal, 61.30% confidence
# metal (0.61295)
# pop (0.17211)
# jazz (0.09677)
# hiphop (0.07100)
# reggae (0.02829)
# classical (0.01888)
#
# metal.00008.jpg
# ---------------------------------------
# the object appears to be metal, 43.29% confidence
# metal (0.43289)
# jazz (0.24690)
# pop (0.18834)
# hiphop (0.09990)
# reggae (0.02580)
# classical (0.00616)
#
# metal.00009.jpg
# ---------------------------------------
# the object appears to be metal, 66.67% confidence
# metal (0.66674)
# jazz (0.12315)
# pop (0.09923)
# hiphop (0.07362)
# reggae (0.03539)
# classical (0.00187)
#
# pop.00000.jpg
# ---------------------------------------
# the object appears to be pop, 46.82% confidence
# pop (0.46816)
# jazz (0.33733)
# metal (0.07517)
# hiphop (0.05586)
# reggae (0.05504)
# classical (0.00844)
#
# pop.00001.jpg
# ---------------------------------------
# the object appears to be pop, 66.75% confidence
# pop (0.66749)
# hiphop (0.15521)
# reggae (0.07862)
# jazz (0.05172)
# metal (0.04558)
# classical (0.00139)
#
# pop.00002.jpg
# ---------------------------------------
# the object appears to be pop, 32.91% confidence
# pop (0.32907)
# jazz (0.30415)
# metal (0.26450)
# hiphop (0.03724)
# reggae (0.03566)
# classical (0.02938)
#
# pop.00003.jpg
# ---------------------------------------
# the object appears to be metal, 64.61% confidence
# metal (0.64613)
# pop (0.13190)
# jazz (0.10740)
# hiphop (0.06779)
# reggae (0.04538)
# classical (0.00141)
#
# pop.00004.jpg
# ---------------------------------------
# the object appears to be jazz, 53.42% confidence
# jazz (0.53417)
# metal (0.37032)
# pop (0.05234)
# reggae (0.02567)
# hiphop (0.01643)
# classical (0.00107)
#
# pop.00005.jpg
# ---------------------------------------
# the object appears to be jazz, 79.93% confidence
# jazz (0.79932)
# pop (0.08776)
# metal (0.05438)
# hiphop (0.02663)
# classical (0.01725)
# reggae (0.01466)
#
# pop.00006.jpg
# ---------------------------------------
# the object appears to be jazz, 51.52% confidence
# jazz (0.51523)
# metal (0.26129)
# pop (0.09550)
# reggae (0.07259)
# hiphop (0.04925)
# classical (0.00614)
#
# pop.00007.jpg
# ---------------------------------------
# the object appears to be jazz, 77.87% confidence
# jazz (0.77868)
# pop (0.14155)
# metal (0.02761)
# classical (0.02725)
# reggae (0.01480)
# hiphop (0.01011)
#
# pop.00008.jpg
# ---------------------------------------
# the object appears to be jazz, 60.35% confidence
# jazz (0.60353)
# metal (0.19818)
# pop (0.14279)
# reggae (0.02719)
# hiphop (0.01913)
# classical (0.00918)
#
# pop.00009.jpg
# ---------------------------------------
# the object appears to be metal, 42.84% confidence
# metal (0.42838)
# jazz (0.23468)
# pop (0.18097)
# hiphop (0.11348)
# reggae (0.03991)
# classical (0.00259)
#
# reggae.00000.jpg
# ---------------------------------------
# the object appears to be jazz, 33.40% confidence
# jazz (0.33398)
# pop (0.28871)
# reggae (0.23629)
# metal (0.07423)
# classical (0.03397)
# hiphop (0.03282)
#
# reggae.00001.jpg
# ---------------------------------------
# the object appears to be metal, 53.45% confidence
# metal (0.53450)
# jazz (0.18883)
# pop (0.14263)
# reggae (0.06634)
# hiphop (0.05945)
# classical (0.00824)
#
# reggae.00002.jpg
# ---------------------------------------
# the object appears to be pop, 34.13% confidence
# pop (0.34134)
# reggae (0.31854)
# hiphop (0.25131)
# metal (0.05131)
# jazz (0.03100)
# classical (0.00651)
#
# reggae.00003.jpg
# ---------------------------------------
# the object appears to be reggae, 32.59% confidence
# reggae (0.32588)
# metal (0.32202)
# jazz (0.14701)
# pop (0.13759)
# hiphop (0.05993)
# classical (0.00758)
#
# reggae.00004.jpg
# ---------------------------------------
# the object appears to be reggae, 39.96% confidence
# reggae (0.39961)
# pop (0.38147)
# jazz (0.07461)
# hiphop (0.07286)
# classical (0.05020)
# metal (0.02125)
#
# reggae.00005.jpg
# ---------------------------------------
# the object appears to be reggae, 39.16% confidence
# reggae (0.39159)
# hiphop (0.20584)
# pop (0.16786)
# metal (0.11449)
# jazz (0.08759)
# classical (0.03263)
#
# reggae.00006.jpg
# ---------------------------------------
# the object appears to be reggae, 43.66% confidence
# reggae (0.43662)
# pop (0.19604)
# jazz (0.18798)
# metal (0.10599)
# hiphop (0.04183)
# classical (0.03154)
#
# reggae.00007.jpg
# ---------------------------------------
# the object appears to be reggae, 64.75% confidence
# reggae (0.64753)
# pop (0.14256)
# hiphop (0.08987)
# metal (0.07578)
# jazz (0.03285)
# classical (0.01140)
#
# reggae.00008.jpg
# ---------------------------------------
# the object appears to be pop, 39.91% confidence
# pop (0.39913)
# jazz (0.31743)
# reggae (0.13988)
# metal (0.10217)
# hiphop (0.02974)
# classical (0.01165)
#
# reggae.00009.jpg
# ---------------------------------------
# the object appears to be reggae, 57.41% confidence
# reggae (0.57406)
# metal (0.16290)
# jazz (0.10715)
# hiphop (0.07968)
# pop (0.07342)
# classical (0.00279)

# %%
print("True positives")
print(TP)
print("False negatives")
print(FN)
print("False positives")
print(FP)

TN = {
'classical': 0,
'hiphop': 0,
'jazz': 0,
'metal': 0,
'pop': 0,
'reggae': 0
}

for genre in TN.keys():
    TN[genre] = 50 - FP[genre]
print("True Negatives")
print(TN)

accuracy = 0
total = 0

for genre in TP.keys():
    accuracy += TP[genre]
    total += TP[genre]

for genre in FP.keys():
    total += FN[genre]

accuracy /= (total/100)
# print(total)
print("Accuracy = " + str(accuracy))

# for genre in overallConfidence.keys():
#     overallConfidence[genre] /= 10
#     confidenceWhenWrong[genre] /= 10
#     confidenceWhenRight[genre] /= 10

# print(overallConfidence)
# print(confidenceWhenWrong)
# print(confidenceWhenRight)
# Out:
# True positives
# {'classical': 9, 'hiphop': 9, 'jazz': 8, 'metal': 8, 'pop': 3, 'reggae': 6}
# False negatives
# {'classical': 1, 'hiphop': 1, 'jazz': 2, 'metal': 2, 'pop': 7, 'reggae': 4}
# False positives
# {'classical': 1, 'hiphop': 0, 'jazz': 8, 'metal': 5, 'pop': 3, 'reggae': 0}
# True Negatives
# {'classical': 49, 'hiphop': 50, 'jazz': 42, 'metal': 45, 'pop': 47, 'reggae': 50}
# Accuracy = 71.66666666666667

# %%
precision = {
'classical': 0,
'hiphop': 0,
'jazz': 0,
'metal': 0,
'pop': 0,
'reggae': 0
}
recall = {
'classical': 0,
'hiphop': 0,
'jazz': 0,
'metal': 0,
'pop': 0,
'reggae': 0
}

for genre in precision.keys():
    precision[genre] = TP[genre] / (TP[genre] + FP[genre])
    precision[genre] = "{0:.2f}".format(precision[genre])
    recall[genre] = TP[genre] / (TP[genre] + FN[genre])
    recall[genre] = "{0:.2f}".format(recall[genre])
    
print("Precision")
print(precision)
print("Recall")
print(recall)
# Out:
# Precision
# {'classical': '0.90', 'hiphop': '1.00', 'jazz': '0.50', 'metal': '0.62', 'pop': '0.50', 'reggae': '1.00'}
# Recall
# {'classical': '0.90', 'hiphop': '0.90', 'jazz': '0.80', 'metal': '0.80', 'pop': '0.30', 'reggae': '0.60'}
